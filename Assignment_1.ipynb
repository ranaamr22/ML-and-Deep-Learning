# %% [markdown]
# <a href="https://colab.research.google.com/github/ranaamr22/ML-and-Deep-Learning/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><font size = 8><b>Digital Image Processing</b></font></center></br></br>
# <center><font size = 6><b>Assignment 1</b></font></center>
#
# ### Name:Rana Amr Abdel Naby Abdel Gawad
# ### ID:2000256
# ### Email:2000256@eng.asu.edu.eg

# %% [markdown]
# # 1. Difference Detection Between Two Images

# %% [markdown]
# Comparison of images is a fundamental task in image-based quality control. It is used in manufacturing industries to check that the product image is similar to good-quality product image.</br></br>
# <font size = "3">*In this section, we will highlight the differences between the given two images.*</font>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pylab

pylab.rcParams['figure.figsize'] = [10.,8.]

# %matplotlib inline

# Read the two images
image1 = cv2.imread("image1.jpg", cv2.IMREAD_COLOR)
image2 = cv2.imread("image2.jpg", cv2.IMREAD_COLOR)

# TODO: Display the two images using plt (0.25 mark)
image1=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)
plt.imshow(image1)
plt.show()

plt.imshow(image2)
plt.show()

# %%
# TODO: Check image differences (0.5 mark)
imageDiff=cv2.absdiff(image1,image2)
plt.imshow(imageDiff)
plt.show()
# TODO: Create a mask with ones corresponding to the pixels having differences  (2 marks)
imageGray=cv2.cvtColor(imageDiff,cv2.COLOR_RGB2GRAY)
mask=cv2.thre

# TODO: Apply the mask on the two images to get the differences (hint: multiply the image by the mask)  (1 mark)


# TODO: Display the two images differences using plt  (0.25 mark)

# %% [markdown]
# # 2. Histogram Equalization

# %% [markdown]
# Histogram equalization is the process used to transfer the gray levels so that the histogram of the resulting image is equalized to be a constant (theoretically).
# <font size="5"><p style="text-align: center;">$s_{k} = T(r_{k}) = \frac{L-1}{MN}\sum \limits _{j=1} ^{k}n_{j}$</p></font></br>
# <font size="3">where:</br>s: is the output intensity</br> k: is the intensity level contour = $ 0, 1, 2,....., L - 1$</br>  L: total number of intensity levels</br>  $n_{j}$: histogram result at intensity j (pixels number of intensity j)</br>  $MN$: is the image size</font></br></br>
# <font size="3">*In this section, we will run histogram equalization on a low-contrast image.*</font>

# %%
# Read the low_contrast image
low_contrast = cv2.imread("low_contrast_image.jpg", cv2.IMREAD_GRAYSCALE)

# TODO: Display the low contrast image using plt. Note that it is a grayscale image  (0.25 mark)

# %%
# TODO: Find the histogram of the image  (0.5 mark)


# TODO: Plot the histogram with x-label: Intensity, y-label: Pixels number, title: Histogram of low contrast image  (0.25 mark)

# %%
# Convert the histogram array to 1D
h = h.ravel()
# Create a copy of the original image
equalized_image = np.copy(low_contrast)

# Initialize sum, L, M, N
sum = 0
L = h.shape[0]
M, N = low_contrast.shape

# Create an empty vector to hold the transformation function points
T = np.zeros((256, 1), np.uint8)

# %%
# TODO: Loop over 1D array of histogram to calculate s value of each k (4 marks)
# 1. Modify the sum
# 2. Compute s value
# 3. Round s to the nearest integer
# 4. Replace r intensities in the original image with the computed s intensity
# 5. Add a point (r,s) to the T vector

# %%
# TODO: Plot the transformation function (0.5 mark)

# %%
# TODO: Plot the histogram after equalization (0.25 mark)
# Use x-label: Intensity, y-label: Pixels number, title: Histogram of equalized image

# %%
# TODO: Display the low contrast and the new equalized images using plt (0.25 mark)
